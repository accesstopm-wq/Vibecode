# %%
SmallGroup(960,11358);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 SmallGroup(960,11358);
#
# NameError: name 'SmallGroup' is not defined
